# %% [markdown]
# # Create dataset
#
# This notebook pretends to create an analyse the main csv file and dataset.

# %% [markdown]
# ### Initial setup

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from auxiliary.auxiliary_funcs import create_merged_dataset

csv_files_path = 'csv_files/'
output_file ="dataset.csv"

# %%
df = create_merged_dataset(csv_files_path, output_file)
df.drop_duplicates(inplace=True)
df.sort_values(by='local', inplace=True)
df.to_csv(output_file, index=False)

# %%
df
# Out:
#                   local  ensino_secundario_completo  total_medio_pensoes  \
# 158            Abrantes                         1.0                  1.0
# 138     Aguiar da Beira                         0.0                  0.0
# 248           Alandroal                         0.0                  1.0
# 99   Albergaria-a-Velha                         1.0                  1.0
# 262           Albufeira                         2.0                  1.0
# ..                  ...                         ...                  ...
# 151             Vouzela                         0.0                  0.0
# 98               Águeda                         1.0                  1.0
# 252               Évora                         2.0                  1.0
# 103              Ílhavo                         2.0                  1.0
# 94               Óbidos                         1.0                  1.0
#
#      beneficiarios_rsi_por_1000hab  taxa_criminalidade  \
# 158                            1.0                 0.0
# 138                            0.0                 0.0
# 248                            0.0                 0.0
# 99                             0.0                 0.0
# 262                            1.0                 1.0
# ..                             ...                 ...
# 151                            0.0                 0.0
# 98                             0.0                 1.0
# 252                            0.0                 1.0
# 103                            0.0                 1.0
# 94                             0.0                 0.0
#
#      retencao_desistencia_ensino_basico  num_pedidos_residencia  \
# 158                                 1.0                     0.0
# 138                                 0.0                     0.0
# 248                                 0.0                     0.0
# 99                                  0.0                     0.0
# 262                                 1.0                     0.0
# ..                                  ...                     ...
# 151                                 0.0                     0.0
# 98                                  0.0                     0.0
# 252                                 0.0                     0.0
# 103                                 0.0                     0.0
# 94                                  1.0                     0.0
#
#      empregada_por_conta_outrem_com_ensino_superior  \
# 158                                             1.0
# 138                                             0.0
# 248                                             0.0
# 99                                              1.0
# 262                                             0.0
# ..                                              ...
# 151                                             1.0
# 98                                              1.0
# 252                                             1.0
# 103                                             1.0
# 94                                              1.0
#
#      taxa_bruta_escolarizacao_ensino_secundario  ganho_mensal  ...  \
# 158                                         2.0           1.0  ...
# 138                                         1.0           0.0  ...
# 248                                         0.0           0.0  ...
# 99                                          1.0           1.0  ...
# 262                                         1.0           1.0  ...
# ..                                          ...           ...  ...
# 151                                         2.0           0.0  ...
# 98                                          1.0           1.0  ...
# 252                                         2.0           1.0  ...
# 103                                         1.0           1.0  ...
# 94                                          0.0           1.0  ...
#
#      pop_empregada_outrem_escalão  taxa_emprego  credito_habitacao_permanente  \
# 158                           0.0           0.0                           0.0
# 138                           0.0           0.0                           2.0
# 248                           0.0           1.0                           1.0
# 99                            0.0           2.0                           1.0
# 262                           0.0           1.0                           2.0
# ..                            ...           ...                           ...
# 151                           0.0           1.0                           0.0
# 98                            0.0           2.0                           1.0
# 252                           0.0           2.0                           1.0
# 103                           0.0           2.0                           1.0
# 94                            0.0           1.0                           2.0
#
#      votos_nulos_assembleias_municipais  \
# 158                                 0.0
# 138                                 0.0
# 248                                 1.0
# 99                                  0.0
# 262                                 0.0
# ..                                  ...
# 151                                 1.0
# 98                                  1.0
# 252                                 0.0
# 103                                 0.0
# 94                                  0.0
#
#      pop_inscrita_eleicoes_assembleias_municipais  Índice De Renovação  \
# 158                                           0.0                  0.0
# 138                                           0.0                  0.0
# 248                                           0.0                  0.0
# 99                                            0.0                  2.0
# 262                                           0.0                  2.0
# ..                                            ...                  ...
# 151                                           0.0                  1.0
# 98                                            1.0                  1.0
# 252                                           1.0                  1.0
# 103                                           0.0                  1.0
# 94                                            0.0                  1.0
#
#      Densidade_População  Num_Beneficiarios_sub_desemprego  rendimento_bruto  \
# 158                  0.0                               0.0               1.0
# 138                  0.0                               0.0               0.0
# 248                  0.0                               0.0               0.0
# 99                   0.0                               0.0               1.0
# 262                  0.0                               1.0               1.0
# ..                   ...                               ...               ...
# 151                  0.0                               0.0               0.0
# 98                   0.0                               0.0               1.0
# 252                  0.0                               0.0               2.0
# 103                  0.0                               0.0               2.0
# 94                   0.0                               0.0               1.0
#
#      matriculados_ensino_nao_superior
# 158                               0.0
# 138                               0.0
# 248                               0.0
# 99                                0.0
# 262                               0.0
# ..                                ...
# 151                               0.0
# 98                                0.0
# 252                               0.0
# 103                               0.0
# 94                                0.0
#
# [316 rows x 34 columns]

# %%
# Set up the plotting environment
plt.figure(figsize=(20, 15))


# Check for unwanted duplicates
plt.figure(figsize=(12, 6))
df['local'].value_counts().head(100).plot(kind='bar', color='orange', edgecolor='black')
plt.title('Frequency of appeareances (should all be 1.0)', fontsize=14)
plt.xlabel('Local')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# Histogram for numerical columns
df.hist(bins=20, figsize=(20, 15), color='skyblue', edgecolor='black')
plt.suptitle('Histograms of Numerical Columns', fontsize=16)
plt.show()
